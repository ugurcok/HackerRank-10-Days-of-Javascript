# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcok/HackerRank-10-Days-of-Javascript/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("insurance.csv")

# %%
veriSeti = pd.read_csv("/content/insurance.csv")

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='age', y='bmi', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
veriSeti.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
x = range(1,11)
y = veriSeti.iloc[0:10, 0]
plt.plot(x,y,"o:")

# %%
veriSeti.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
x = range(1,11)
y = veriSeti.iloc[0:10, 0]
plt.plot(x,y,"o:r")

# %%
plt.plot(x, y, linestyle ="dashed", color="hotpink", linewidth = "5")

# %%
x = np.arange(1, 51)
y = veriSeti.iloc[0:50, 0]
plt.title("ilk 50 müşterinin yaşı ")
plt.xlabel("müşteri ID'si")
plt.ylabel("yaş")
plt.plot(x, y)
plt.grid(color = "red", linestyle = "--", linewidth = 0.5)

# %%
ozet = veriSeti.groupby("region")["charges"].sum()

# %%
etiketler = ozet.index
degerler = ozet.values
renkler = sns.color_palette("viridis", 4)
secim = (0, 0, 0.2, 0)
plt.pie( degerler ,explode = secim, labels = etiketler, autopct = "%%%4.1f", shadow= True, startangle = 360, colors = renkler)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7090244880>,
# ...
#  [Text(0.7908199177572359, 0.7645939168463473, 'northeast'),
#   Text(-0.6919562139901897, 0.8551003437728013, 'northwest'),
#   Text(-0.930927064598197, -0.907400022260626, 'southeast'),
#   Text(0.8342062385956289, -0.7170076369803412, 'southwest')],
#  [Text(0.4313563187766741, 0.4170512273707348, '%24.5'),
#   Text(-0.37743066217646704, 0.46641836933061886, '%22.7'),
#   Text(-0.5728781935988904, -0.5584000136988467, '%30.2'),
#   Text(0.4550215846885248, -0.39109507471654975, '%22.6')])

# %%
fig = plt.figure(figsize= (10, 10))
ax = plt.axes(projection = "3d")
ax.scatter(veriSeti.age, veriSeti.charges, veriSeti.children, color = "darkblue")
ax.set_xlabel("yaş")
ax.set_ylabel("charges")
ax.set_zlabel("children", rotation=90)
ax.zaxis.labelpad= -0.50
plt.title("3 BOYUTLU SERPİLME DİYAGRAMI")
# Out:
# Text(0.5, 0.92, '3 BOYUTLU SERPİLME DİYAGRAMI')

# %%
sns.histplot(data = veriSeti, x="age", color="hotpink")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a0a7f86358d> in <cell line: 1>()
# ----> 1 sns.histplot(data = veriSeti, x="age", color="hotpink")
#
# NameError: name 'sns' is not defined

# %%
sns.histplot(data=veriSeti, y = "children", color= "blue", bins=3)
# Out:
# <Axes: xlabel='Count', ylabel='children'>

# %%
sns.histplot(data=veriSeti, y="age")
# Out:
# <Axes: xlabel='Count', ylabel='age'>

# %%
sns.histplot(data=veriSeti, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>
